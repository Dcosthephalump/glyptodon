# %% [markdown]
# # Pipeline
#
# > This module instantiates the ```Pipeline``` object and adds the relevant panels to itself.

# %%
#| default_exp pipelinePanel

# %%
#| hide
from nbdev.showdoc import *
from fastcore.utils import *

# %% [markdown]
# This module relies on the widgetCalls and mansucriptFiles modules to work. This is the import statement for those libraries as well as some others.

# %%
#| export
import ipywidgets as widgets
import param
import panel as pn
pn.extension('ipywidgets')

import glyptodon.widgetCallsPanel as wc
from glyptodon.manuscriptFiles import *
from glyptodon.selectionPanel import Selection
from glyptodon.informationPanel import Information
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='6244c2d0-adec-4aa4-b089-3fd7894ab5a4'>
#   <div id="f6dcd058-4204-410b-abf0-dfd6f48968b4" data-root-id="6244c2d0-adec-4aa4-b089-3fd7894ab5a4" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
pipeline = pn.pipeline.Pipeline()

# %%
pipeline.add_stage('Selection', Selection)
pipeline.add_stage('Information', Information)

pipeline
# Out:
# Pipeline:
#     [0] Selection: Selection()
#     [1] Information: Information()

# %%
#| hide
import nbdev; nbdev.nbdev_export()
