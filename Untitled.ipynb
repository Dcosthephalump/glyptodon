# %%
import numpy as np
import panel as pn
import ipywidgets as ipw

pn.extension('ipywidgets')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
date   = ipw.DatePicker(description='Date')
slider = ipw.FloatSlider(description='Float')
play   = ipw.Play()

layout = ipw.HBox(children=[date, slider, play])

pn.panel(layout)
# Out:
# IPyWidget(HBox)

# %%
class Widge1(param.Parameterized):
    
    date   = ipw.DatePicker(description='Date')
    slider = ipw.FloatSlider(description='Float')
    play   = ipw.Play()

    layout = ipw.HBox(children=[date, slider, play])

    def panel(self):
        return layout

# %%
widgeline = pn.pipeline.Pipeline()

# %%
widge1 = Widge1()

widge1.panel()
# Out:
# HBox(children=(DatePicker(value=None, description='Date', step=1), FloatSlider(value=79.80000000000001, descri…

# %%
widgeline.add_stage('Widge 1', Widge1)

widgeline
# Out:
# Pipeline:
#     [0] Widge 1: Widge1()
